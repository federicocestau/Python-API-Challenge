# %%
g_key= 'AIzaSyDoGOkawORICQIhpxIn-yvXm8LzQwyaY8g'
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# %%
weather_df = pd.read_csv('C:/Users/User/Api Homework/Cities.csv')

# %%
weather_df.head()
# Out:
#    City_ID       City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  ostrovnoy           2      RU  1558378754        72  68.05
# 1        1  mahebourg          75      MU  1558378503        74 -20.41
# 2        2    qaanaaq          25      GL  1558378755        73  77.48
# 3        3     zhuhai           0      CN  1558378755        39  40.71
# 4        4  cape town          20      ZA  1558378755        76 -33.93
#
#       Lng  Max Temp  Wind Speed
# 0   39.51     37.50        7.16
# 1   57.70     78.80       11.41
# 2  -69.36     22.20        2.37
# 3  112.04     44.60        4.47
# 4   18.42     55.99        8.05

# %%
weather_df[["City","Lat","Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed"]]
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed
# 0      ostrovnoy  68.05   39.51     37.50        72           2        7.16
# 1      mahebourg -20.41   57.70     78.80        74          75       11.41
# 2        qaanaaq  77.48  -69.36     22.20        73          25        2.37
# 3         zhuhai  40.71  112.04     44.60        39           0        4.47
# 4      cape town -33.93   18.42     55.99        76          20        8.05
# ..           ...    ...     ...       ...       ...         ...         ...
# 543       yabrud  33.97   36.66     80.60        32           0        8.05
# 544      paraiso  24.01 -104.61     84.20         4           5       16.11
# 545      veraval  49.65    0.71     61.00        62           0        8.05
# 546  novyy urgal  51.07  132.56     49.74        93         100        2.68
# 547      tongren  27.72  109.18     55.86        64           4        2.84
#
# [548 rows x 7 columns]

# %%
locations = weather_df[["Lat", "Lng"]]
humidity = weather_df["Humidity"].astype(float)
locations
# Out:
#        Lat     Lng
# 0    68.05   39.51
# 1   -20.41   57.70
# 2    77.48  -69.36
# 3    40.71  112.04
# 4   -33.93   18.42
# ..     ...     ...
# 543  33.97   36.66
# 544  24.01 -104.61
# 545  49.65    0.71
# 546  51.07  132.56
# 547  27.72  109.18
#
# [548 rows x 2 columns]

# %%
gmaps.configure(api_key=g_key)

fig_layout = {
    'width': '700px',
    'height': '500px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=fig_layout)


heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=3)



fig.add_layer(heat_layer)


fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…

# %%
weather_2_df = weather_df.loc[(weather_df["Max Temp"]>70) & (weather_df["Max Temp"]<85) & (weather_df["Wind Speed"]<50)
                                 & (weather_df["Cloudiness"]==0)]
weather_2_df = weather_2_df.dropna()
weather_2_df.head()
# Out:
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 56        56            pisco           0      PE  1558378764        30
# 70        70     ponta do sol           0      BR  1558378767        57
# 88        88         cidreira           0      BR  1558378770        66
# 114      114           koumac           0      NC  1558378775        68
# 125      125  arraial do cabo           0      BR  1558378491        78
#
#        Lat     Lng  Max Temp  Wind Speed
# 56  -13.71  -76.20     75.99       11.41
# 70  -20.63  -46.00     73.68        5.32
# 88  -30.17  -50.22     76.56        5.50
# 114 -20.56  164.28     74.40       12.86
# 125 -22.97  -42.02     84.20        4.70

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
base_url
# Out:
# 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# %%
hotel_df = weather_2_df

params = {
    "radius": 5000,
    "types": "Hotels",
    "key": g_key
}

for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]

    
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

response = requests.get(base_url, params=params).json()
response
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CqQCHQEAAPDsjvuzFEtHxdWI3_czTRfOvCXs9qYgoIhufkZy04lEiiBkooZuUE2qDLkSkROHLO_RurZ_uxjsypMNt7A0oSHMkgV_LXtfnuxzIJOD2agiD9Be6w47pj5JeFSypVz5NZbDSF2AMryNWsctkdxf_tzm7X_ebSwFYEde_1BzE14rl3cLb1n6aBVEf_QhSTqZK2UzPLxlCPyu7si_Tu0-jBa8_fXtjEHOs1gffF221nS5l6v0vnQJbCgDJbX-Pl-5cNQmdpohKmhGtTGqGkromYwZ72ffw_qAJ-HmNofhg0asyhtR-NdSl_J7Jg8vPEhgEcHshkmuvstqqZLpKOZkNjb4v-Yr1aE7hEuFxbkafCHsodbo1PeqCxHFf8bxdzs6SxIQSAlsjdsJpESxyTEri07yTxoUgq9-v00drObpcDxriRUJ0M87VyM',
#  'results': [{'geometry': {'location': {'lat': 33.9717649, 'lng': 36.6579649},
#     'viewport': {'northeast': {'lat': 33.9869259, 'lng': 36.6854954},
#      'southwest': {'lat': 33.9547519, 'lng': 36.6432666}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png',
#    'id': 'da7e820d2dbbdc383d8c64e6b34387781f0b27bf',
#    'name': 'Yabrud',
#    'photos': [{'height': 360,
# ...

# %%
for index, row in hotel_df.iterrows():
    
    lat = row["Lat"]
    lng = row["Lng"]

    
    params["location"] = f"{lat},{lng}"
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

  
    print(f"Retrieving Results for Index {index}: {row['City']}.")
    response = requests.get(base_url, params=params).json()
   
    results = response['results']
    
    try:
        print(f"Closest hotel is {results[0]['name']}.")
        hotel_df.loc[index, 'Hotel Name'] = results[0]['name']
        
    except (KeyError, IndexError):
        print("Missing field/result... skipping.")
        
    print("------------")
# Out:
# Retrieving Results for Index 56: pisco.
# Closest hotel is Pisco.
# ------------
# Retrieving Results for Index 70: ponta do sol.
# Closest hotel is Capitólio.
# ------------
# Retrieving Results for Index 88: cidreira.
# Closest hotel is CIDREIRA.
# ------------
# Retrieving Results for Index 114: koumac.
# Closest hotel is Koumac.
# ------------
# Retrieving Results for Index 125: arraial do cabo.
# Closest hotel is Cabo Frio.
# ------------
# Retrieving Results for Index 138: morondava.
# Closest hotel is Morondava.
# ------------
# Retrieving Results for Index 139: vaini.
# Closest hotel is Jagalbet.
# ------------
# Retrieving Results for Index 176: nador.
# Closest hotel is Nador.
# ------------
# Retrieving Results for Index 297: mogok.
# Closest hotel is Mogok.
# ------------
# Retrieving Results for Index 316: gunjur.
# Closest hotel is Gunjur.
# ------------
# Retrieving Results for Index 391: namibe.
# Closest hotel is Namibe.
# ------------
# ...

# %%
hotel_df.head()
# Out:
#      City_ID             City  Cloudiness Country        Date  Humidity  \
# 56        56            pisco           0      PE  1558378764        30
# 70        70     ponta do sol           0      BR  1558378767        57
# 88        88         cidreira           0      BR  1558378770        66
# 114      114           koumac           0      NC  1558378775        68
# 125      125  arraial do cabo           0      BR  1558378491        78
#
#        Lat     Lng  Max Temp  Wind Speed Hotel Name
# 56  -13.71  -76.20     75.99       11.41      Pisco
# 70  -20.63  -46.00     73.68        5.32  Capitólio
# 88  -30.17  -50.22     76.56        5.50   CIDREIRA
# 114 -20.56  164.28     74.40       12.86     Koumac
# 125 -22.97  -42.02     84.20        4.70  Cabo Frio

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
marker_layer=gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)
#Display map
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='500px', margin='0 auto 0 auto', padding='1px', wi…
