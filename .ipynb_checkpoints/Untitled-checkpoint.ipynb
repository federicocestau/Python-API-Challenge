# %%
# Import API key
weather_api_key="d0cb7612d8e4acdc7e895ce9b00e46a3"

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
output_data_file ="C:/Users/User/Api Homework/Cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)

lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=300)
lngs = np.random.uniform(low=-180.000, high=180.000, size=300)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 179

# %%
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lng = []
country = []
date = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
key = weather_api_key


query_url = f"{url}appid={key}&units={units}&q="

response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': -56.09, 'lat': -9.88},
#  'weather': [{'id': 501,
#    'main': 'Rain',
#    'description': 'moderate rain',
#    'icon': '10n'}],
#  'base': 'stations',
#  'main': {'temp': 74.32,
#   'feels_like': 81.34,
#   'temp_min': 74.32,
#   'temp_max': 74.32,
#   'pressure': 1011,
#   'humidity': 96,
#   'sea_level': 1011,
#   'grnd_level': 977},
#  'wind': {'speed': 4, 'deg': 296},
#  'rain': {'3h': 3.38},
#  'clouds': {'all': 68},
#  'dt': 1583889438,
#  'sys': {'country': 'BR', 'sunrise': 1583833712, 'sunset': 1583877641},
#  'timezone': -14400,
#  'id': 6316343,
#  'name': 'Alta Floresta',
#  'cod': 200}

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        id = response['id']
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print (f"{city} ID: {id} has been pulled from Open Weather Map")
    except (KeyError, IndexError):
        country.append(None)
        date.append(None)
        lat.append(None)
        lng.append(None)
        max_temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        print(f"{city} not found, going to keep going!")
# Out:
# alta floresta ID: 6316343 has been pulled from Open Weather Map
# krasnyy tekstilshchik not found, going to keep going!
# cam ranh ID: 1586350 has been pulled from Open Weather Map
# atuona ID: 4020109 has been pulled from Open Weather Map
# whitecourt ID: 6180285 has been pulled from Open Weather Map
# ushuaia ID: 3833367 has been pulled from Open Weather Map
# mitsamiouli ID: 921786 has been pulled from Open Weather Map
# krasnogorodsk ID: 542378 has been pulled from Open Weather Map
# mataura ID: 6201424 has been pulled from Open Weather Map
# lebu ID: 3883457 has been pulled from Open Weather Map
# gravdal ID: 3155152 has been pulled from Open Weather Map
# veere ID: 2745739 has been pulled from Open Weather Map
# punta arenas ID: 3874787 has been pulled from Open Weather Map
# killam ID: 5991888 has been pulled from Open Weather Map
# chaozhou ID: 1815395 has been pulled from Open Weather Map
# thompson ID: 6165406 has been pulled from Open Weather Map
# jinchang ID: 1805733 has been pulled from Open Weather Map
# honiara ID: 2108502 has been pulled from Open Weather Map
# ankang ID: 1789065 has been pulled from Open Weather Map
# bluff ID: 2206939 has been pulled from Open Weather Map
# brae ID: 2654970 has been pulled from Open Weather Map
# busselton ID: 2075265 has been pulled from Open Weather Map
# butaritari ID: 2110227 has been pulled from Open Weather Map
# saint-philippe ID: 935215 has been pulled from Open Weather Map
# kapaa ID: 5848280 has been pulled from Open Weather Map
# hobart ID: 2163355 has been pulled from Open Weather Map
# sarai mir ID: 1257260 has been pulled from Open Weather Map
# manokwari ID: 1636308 has been pulled from Open Weather Map
# helena ID: 5656882 has been pulled from Open Weather Map
# souillac ID: 933995 has been pulled from Open Weather Map
# fortuna ID: 5563839 has been pulled from Open Weather Map
# carnarvon ID: 2074865 has been pulled from Open Weather Map
# qaanaaq ID: 3831208 has been pulled from Open Weather Map
# talnakh ID: 1490256 has been pulled from Open Weather Map
# bilma ID: 2446796 has been pulled from Open Weather Map
# solyanka ID: 490737 has been pulled from Open Weather Map
# okhotsk ID: 2122605 has been pulled from Open Weather Map
# ewo ID: 2260009 has been pulled from Open Weather Map
# kahului ID: 5847411 has been pulled from Open Weather Map
# matara ID: 1235846 has been pulled from Open Weather Map
# cayenne ID: 3382160 has been pulled from Open Weather Map
# severo-yeniseyskiy ID: 1492566 has been pulled from Open Weather Map
# acapulco ID: 3533462 has been pulled from Open Weather Map
# gooik ID: 2797418 has been pulled from Open Weather Map
# brookhaven ID: 4419500 has been pulled from Open Weather Map
# westerland ID: 2810284 has been pulled from Open Weather Map
# dongsheng ID: 1812256 has been pulled from Open Weather Map
# bargal not found, going to keep going!
# nome ID: 5870133 has been pulled from Open Weather Map
# surab ID: 1164306 has been pulled from Open Weather Map
# big spring ID: 5517061 has been pulled from Open Weather Map
# suez ID: 359796 has been pulled from Open Weather Map
# macenta ID: 2417988 has been pulled from Open Weather Map
# broome ID: 5110365 has been pulled from Open Weather Map
# port lincoln ID: 2063036 has been pulled from Open Weather Map
# litoral del san juan not found, going to keep going!
# college ID: 5859699 has been pulled from Open Weather Map
# samusu not found, going to keep going!
# petropavlovsk-kamchatskiy ID: 2122104 has been pulled from Open Weather Map
# sao jose da coroa grande ID: 3388456 has been pulled from Open Weather Map
# mar del plata ID: 3430863 has been pulled from Open Weather Map
# villaviciosa ID: 3104707 has been pulled from Open Weather Map
# lagoa ID: 3372964 has been pulled from Open Weather Map
# saint george ID: 5546220 has been pulled from Open Weather Map
# aporawan not found, going to keep going!
# camacupa ID: 3351014 has been pulled from Open Weather Map

# %%
DataFrame= pd.DataFrame({'City':cities,'Cloudiness':cloudiness,'Country':country,'Date':date,'Humidity':humidity,
                       'Lat':lat,'Lng':lng,'Max Temp':max_temp,'Wind Speed':wind_speed})

DataFrame.head()
# Out:
#                     City  Cloudiness Country          Date  Humidity    Lat  \
# 0          alta floresta        68.0      BR  1.583889e+09      96.0  -9.88
# 1  krasnyy tekstilshchik         NaN    None           NaN       NaN    NaN
# 2               cam ranh        40.0      VN  1.583889e+09      94.0  11.92
# 3                 atuona        44.0      PF  1.583889e+09      72.0  -9.80
# 4             whitecourt        75.0      CA  1.583889e+09      41.0  54.15
#
#       Lng  Max Temp  Wind Speed
# 0  -56.09     74.32        4.00
# 1     NaN       NaN         NaN
# 2  109.16     82.40        8.05
# 3 -139.03     81.77       16.17
# 4 -115.69     42.80       12.75

# %%
DataFrame.to_csv("C:/Users/User/Api Homework/DataFrame_Output.csv")

# %%
plt.scatter(DataFrame['Lat'], DataFrame["Max Temp"])

plt.title(f'City Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)

plt.savefig("C:/Users/User/Api Homework/LatitudevsTemperature Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Humidity'])

plt.title(f'City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig("C:/Users/User/Api Homework/LatitudevsHumidity Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Cloudiness'])

plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

plt.savefig("C:/Users/User/Api Homework/LatitudevsCloudiness Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Wind Speed'])

plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

plt.savefig("C:/Users/User/Api Homework/LatitudevsWind Speed Plot.png")
plt.show()

# %%
def Lin_Reg(latitude, variable):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, variable)
    regress_values = latitude * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(latitude, variable)
    plt.plot(latitude,regress_values,"r-")
    plt.annotate(line_eq,(max(latitude)-6,max(variable)-10),fontsize=15,color="red")
    return rvalue

# %%
Northern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]>0),:]
Northern_Hemisphere_df
# Out:
#                           City  Cloudiness Country          Date  Humidity  \
# 2                     cam ranh        40.0      VN  1.583889e+09      94.0
# 4                   whitecourt        75.0      CA  1.583889e+09      41.0
# 7                krasnogorodsk       100.0      RU  1.583889e+09      86.0
# 10                     gravdal       100.0      NO  1.583889e+09      74.0
# 11                       veere       100.0      NL  1.583889e+09      93.0
# ..                         ...         ...     ...           ...       ...
# 169                    college         1.0      US  1.583889e+09      64.0
# 171  petropavlovsk-kamchatskiy        40.0      RU  1.583889e+09      58.0
# 174               villaviciosa         0.0      ES  1.583889e+09      81.0
# 175                      lagoa       100.0      PT  1.583889e+09      91.0
# 176               saint george        90.0      US  1.583889e+09      48.0
#
#        Lat     Lng  Max Temp  Wind Speed
# 2    11.92  109.16     82.40        8.05
# 4    54.15 -115.69     42.80       12.75
# 7    56.83   28.28     41.05        9.26
# 10   68.12   13.50     34.95       24.81
# 11   51.55    3.67     54.00       32.21
# ..     ...     ...       ...         ...
# 169  64.86 -147.80      1.40        5.82
# 171  53.05  158.65     24.80        4.47
# 174  43.48   -5.44     50.00        5.82
# 175  39.05  -27.98     57.51       23.85
# 176  37.10 -113.58     62.60        6.93
#
# [102 rows x 9 columns]

# %%
Southern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]<0),:]
Southern_Hemisphere_df.head()
# Out:
#             City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0  alta floresta        68.0      BR  1.583889e+09      96.0  -9.88  -56.09
# 3         atuona        44.0      PF  1.583889e+09      72.0  -9.80 -139.03
# 5        ushuaia        20.0      AR  1.583889e+09      70.0 -54.80  -68.30
# 6    mitsamiouli        43.0      KM  1.583889e+09      71.0 -11.38   43.28
# 8        mataura        87.0      NZ  1.583889e+09      67.0 -46.19  168.86
#
#    Max Temp  Wind Speed
# 0     74.32        4.00
# 3     81.77       16.17
# 5     46.40        5.82
# 6     83.73        4.90
# 8     55.99        4.00

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Max Temp"])

plt.title('Northern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8721595142036068

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Max Temp"])

plt.title('Southern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.7620303885008254

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Humidity"])

plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.22495067578251235

# %%
Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Humidity"])

plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-22a4a46b825c> in <module>
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Humidity (%)')
# ----> 6 print(f"The r-squared is: {rvalue}")
#       7 plt.show()
#
# NameError: name 'rvalue' is not defined

# %%
Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Cloudiness"])

plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b700906d19e5> in <module>
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Cloudiness (%)')
# ----> 6 print(f"The r-squared is: {rvalue}")
#       7 plt.show()
#
# NameError: name 'rvalue' is not defined

# %%
Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Cloudiness"])

plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-82d8db28eb9f> in <module>
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Cloudiness (%)')
# ----> 6 print(f"The r-squared is: {rvalue}")
#       7 plt.show()
#
# NameError: name 'rvalue' is not defined

# %%
Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Wind Speed"])

plt.title('Northern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-bc167bf7fba4> in <module>
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Win Speed (mph)')
# ----> 6 print(f"The r-squared is: {rvalue}")
#       7 plt.show()
#
# NameError: name 'rvalue' is not defined

# %%
Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Wind Speed"])

plt.title('Southern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-55912195f443> in <module>
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Win Speed (mph)')
# ----> 6 print(f"The r-squared is: {rvalue}")
#       7 plt.show()
#
# NameError: name 'rvalue' is not defined
