# %%
# Import API key
weather_api_key="d0cb7612d8e4acdc7e895ce9b00e46a3"

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
output_data_file ="C:/Users/User/Api Homework/Cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)

lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=700)
lngs = np.random.uniform(low=-180.000, high=180.000, size=700)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 382

# %%
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lng = []
country = []
date = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
key = weather_api_key


query_url = f"{url}appid={key}&units={units}&q="

response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': 122.53, 'lat': -4.94},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 79.16,
#   'feels_like': 88.84,
#   'temp_min': 79.16,
#   'temp_max': 79.16,
#   'pressure': 1010,
#   'humidity': 85,
#   'sea_level': 1010,
#   'grnd_level': 1000},
#  'wind': {'speed': 0.43, 'deg': 37},
#  'clouds': {'all': 100},
#  'dt': 1585610289,
#  'sys': {'country': 'ID', 'sunrise': 1585605120, 'sunset': 1585648546},
#  'timezone': 28800,
#  'id': 1640972,
#  'name': 'Katobu',
#  'cod': 200}

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        id = response['id']
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print (f"{city} ID: {id} has been pulled from Open Weather Map")
    except (KeyError, IndexError):
        country.append(None)
        date.append(None)
        lat.append(None)
        lng.append(None)
        max_temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        print(f"{city} not found, going to keep going!")
# Out:
# mandalgovi ID: 2030065 has been pulled from Open Weather Map
# hilo ID: 5855927 has been pulled from Open Weather Map
# nanortalik ID: 3421765 has been pulled from Open Weather Map
# tsihombe not found, going to keep going!
# cabo san lucas ID: 3985710 has been pulled from Open Weather Map
# xianshuigu ID: 1790379 has been pulled from Open Weather Map
# flin flon ID: 5954718 has been pulled from Open Weather Map
# cagayan de tawi-tawi not found, going to keep going!
# grand river south east not found, going to keep going!
# zilair ID: 462626 has been pulled from Open Weather Map
# boa vista ID: 3664980 has been pulled from Open Weather Map
# bluff ID: 2206939 has been pulled from Open Weather Map
# petropavlovka ID: 2017979 has been pulled from Open Weather Map
# jember ID: 1642588 has been pulled from Open Weather Map
# punta arenas ID: 3874787 has been pulled from Open Weather Map
# kapaa ID: 5848280 has been pulled from Open Weather Map
# amderma not found, going to keep going!
# hermanus ID: 3366880 has been pulled from Open Weather Map
# codrington ID: 2171099 has been pulled from Open Weather Map
# thompson ID: 6165406 has been pulled from Open Weather Map
# oktyabrskiy ID: 515879 has been pulled from Open Weather Map
# taolanaro not found, going to keep going!
# burns lake ID: 5911745 has been pulled from Open Weather Map
# rikitea ID: 4030556 has been pulled from Open Weather Map
# takoradi ID: 2294915 has been pulled from Open Weather Map
# cedar city ID: 5536630 has been pulled from Open Weather Map
# bredasdorp ID: 1015776 has been pulled from Open Weather Map
# jamestown ID: 5122534 has been pulled from Open Weather Map
# hambantota ID: 1244926 has been pulled from Open Weather Map
# ushuaia ID: 3833367 has been pulled from Open Weather Map
# mataura ID: 6201424 has been pulled from Open Weather Map
# barrow ID: 5880054 has been pulled from Open Weather Map
# saint-francois ID: 2980080 has been pulled from Open Weather Map
# hualmay ID: 3939761 has been pulled from Open Weather Map
# san cristobal ID: 3628473 has been pulled from Open Weather Map
# bambanglipuro ID: 1650434 has been pulled from Open Weather Map
# kaitangata ID: 2208248 has been pulled from Open Weather Map
# tateyama ID: 1850523 has been pulled from Open Weather Map
# fortuna ID: 5563839 has been pulled from Open Weather Map
# illoqqortoormiut not found, going to keep going!
# scalea ID: 2523207 has been pulled from Open Weather Map
# rawson ID: 3839307 has been pulled from Open Weather Map
# hendijan not found, going to keep going!
# ola ID: 2122574 has been pulled from Open Weather Map
# melbu ID: 3146160 has been pulled from Open Weather Map
# arraial do cabo ID: 3471451 has been pulled from Open Weather Map
# nabul not found, going to keep going!
# namatanai ID: 2090021 has been pulled from Open Weather Map
# kupang ID: 2057087 has been pulled from Open Weather Map
# te anau ID: 2181625 has been pulled from Open Weather Map
# port elizabeth ID: 964420 has been pulled from Open Weather Map
# ust-kamchatsk not found, going to keep going!
# baykit ID: 1510689 has been pulled from Open Weather Map
# half moon bay ID: 5354943 has been pulled from Open Weather Map
# sao joao da barra ID: 3448903 has been pulled from Open Weather Map
# mahibadhoo ID: 1337605 has been pulled from Open Weather Map
# cape town ID: 3369157 has been pulled from Open Weather Map
# geraldton ID: 2070998 has been pulled from Open Weather Map
# west lorne ID: 6179147 has been pulled from Open Weather Map
# chuy ID: 3443061 has been pulled from Open Weather Map
# kavieng ID: 2094342 has been pulled from Open Weather Map
# bandiagara ID: 2460489 has been pulled from Open Weather Map
# dikson ID: 1507390 has been pulled from Open Weather Map
# sioux lookout ID: 6148373 has been pulled from Open Weather Map
# kazalinsk not found, going to keep going!
# khatanga ID: 2022572 has been pulled from Open Weather Map
# saint anthony ID: 5044290 has been pulled from Open Weather Map
# torbay ID: 6167817 has been pulled from Open Weather Map
# mayumba ID: 2399001 has been pulled from Open Weather Map
# inowroclaw ID: 3097872 has been pulled from Open Weather Map
# narsaq ID: 3421719 has been pulled from Open Weather Map
# longyearbyen ID: 2729907 has been pulled from Open Weather Map
# nguiu not found, going to keep going!
# esso ID: 2125711 has been pulled from Open Weather Map
# nizhneyansk not found, going to keep going!
# paamiut ID: 3421193 has been pulled from Open Weather Map
# waipawa ID: 2206874 has been pulled from Open Weather Map
# berlevag ID: 780687 has been pulled from Open Weather Map
# qaqortoq ID: 3420846 has been pulled from Open Weather Map
# albany ID: 5106841 has been pulled from Open Weather Map
# rio grande ID: 3451138 has been pulled from Open Weather Map
# wolfhagen ID: 2806799 has been pulled from Open Weather Map
# murmashi ID: 524299 has been pulled from Open Weather Map
# hithadhoo ID: 1282256 has been pulled from Open Weather Map
# bengkulu ID: 1649150 has been pulled from Open Weather Map
# hede ID: 1808744 has been pulled from Open Weather Map
# arlit ID: 2447513 has been pulled from Open Weather Map
# bereda ID: 3105522 has been pulled from Open Weather Map
# broome ID: 5110365 has been pulled from Open Weather Map
# yellowknife ID: 6185377 has been pulled from Open Weather Map
# sitka ID: 5557293 has been pulled from Open Weather Map
# bartlesville ID: 4529987 has been pulled from Open Weather Map
# san patricio ID: 3985168 has been pulled from Open Weather Map
# boo ID: 2721259 has been pulled from Open Weather Map
# souillac ID: 933995 has been pulled from Open Weather Map
# georgetown ID: 1735106 has been pulled from Open Weather Map
# saleaula not found, going to keep going!
# saskylakh ID: 2017155 has been pulled from Open Weather Map
# samusu not found, going to keep going!
# vaini ID: 4032243 has been pulled from Open Weather Map
# alindao ID: 240999 has been pulled from Open Weather Map
# tiruttani ID: 1278471 has been pulled from Open Weather Map
# san quintin ID: 3984997 has been pulled from Open Weather Map
# east london ID: 1006984 has been pulled from Open Weather Map
# dalvik ID: 2632287 has been pulled from Open Weather Map
# scottsburgh not found, going to keep going!
# warrington ID: 2634739 has been pulled from Open Weather Map
# panama city ID: 3703443 has been pulled from Open Weather Map
# talnakh ID: 1490256 has been pulled from Open Weather Map
# mahebourg ID: 934322 has been pulled from Open Weather Map
# palabuhanratu not found, going to keep going!
# ancud ID: 3899695 has been pulled from Open Weather Map
# busselton ID: 2075265 has been pulled from Open Weather Map
# magadan ID: 2123628 has been pulled from Open Weather Map
# kodiak ID: 5866583 has been pulled from Open Weather Map
# avarua ID: 4035715 has been pulled from Open Weather Map
# saint-pierre ID: 935214 has been pulled from Open Weather Map
# vila franca do campo ID: 3372472 has been pulled from Open Weather Map
# aksu ID: 1529660 has been pulled from Open Weather Map
# dauphin ID: 5935341 has been pulled from Open Weather Map
# hamilton ID: 4513583 has been pulled from Open Weather Map
# esperance ID: 2071860 has been pulled from Open Weather Map
# new norfolk ID: 2155415 has been pulled from Open Weather Map
# ilulissat ID: 3423146 has been pulled from Open Weather Map
# lebu ID: 3883457 has been pulled from Open Weather Map
# asuncion ID: 3439389 has been pulled from Open Weather Map
# yumen ID: 1528998 has been pulled from Open Weather Map
# kavaratti ID: 1267390 has been pulled from Open Weather Map
# tuktoyaktuk ID: 6170031 has been pulled from Open Weather Map
# nenjiang ID: 2035601 has been pulled from Open Weather Map
# yar-sale ID: 1486321 has been pulled from Open Weather Map
# lyndon ID: 4299562 has been pulled from Open Weather Map
# manzanillo ID: 3547867 has been pulled from Open Weather Map
# port alfred ID: 964432 has been pulled from Open Weather Map
# caxito ID: 2242001 has been pulled from Open Weather Map
# mbaiki ID: 2384770 has been pulled from Open Weather Map
# tual ID: 1623197 has been pulled from Open Weather Map
# atuona ID: 4020109 has been pulled from Open Weather Map
# college ID: 5859699 has been pulled from Open Weather Map
# kruisfontein ID: 986717 has been pulled from Open Weather Map
# flinders ID: 6255012 has been pulled from Open Weather Map
# puerto ayora ID: 3652764 has been pulled from Open Weather Map
# aklavik ID: 5882953 has been pulled from Open Weather Map
# jablah ID: 169304 has been pulled from Open Weather Map
# castro ID: 3466704 has been pulled from Open Weather Map
# tukrah ID: 88834 has been pulled from Open Weather Map
# brighton ID: 2654710 has been pulled from Open Weather Map
# nikolskoye ID: 546105 has been pulled from Open Weather Map
# puerto baquerizo moreno ID: 3652758 has been pulled from Open Weather Map
# diffa ID: 2445704 has been pulled from Open Weather Map
# norman wells ID: 6089245 has been pulled from Open Weather Map
# hwange ID: 889942 has been pulled from Open Weather Map
# necochea ID: 3430443 has been pulled from Open Weather Map
# katsuura ID: 2112309 has been pulled from Open Weather Map
# orumiyeh ID: 121801 has been pulled from Open Weather Map
# lola ID: 2418092 has been pulled from Open Weather Map
# namie ID: 2111704 has been pulled from Open Weather Map
# hovd ID: 1516048 has been pulled from Open Weather Map
# nyuksenitsa ID: 516539 has been pulled from Open Weather Map
# saint-philippe ID: 935215 has been pulled from Open Weather Map
# leningradskiy ID: 2123814 has been pulled from Open Weather Map
# cidreira ID: 3466165 has been pulled from Open Weather Map
# muroto ID: 1856392 has been pulled from Open Weather Map
# provideniya ID: 4031574 has been pulled from Open Weather Map
# hasaki ID: 2112802 has been pulled from Open Weather Map
# port lincoln ID: 2063036 has been pulled from Open Weather Map
# sabha ID: 2212775 has been pulled from Open Weather Map
# muhos ID: 645765 has been pulled from Open Weather Map
# vilyuysk ID: 2013392 has been pulled from Open Weather Map
# rudnogorsk ID: 2017378 has been pulled from Open Weather Map
# port hedland ID: 2063042 has been pulled from Open Weather Map
# lompoc ID: 5367788 has been pulled from Open Weather Map
# eirunepe ID: 3664321 has been pulled from Open Weather Map
# kuminskiy ID: 1501429 has been pulled from Open Weather Map
# pong ID: 1607324 has been pulled from Open Weather Map
# poum ID: 2138555 has been pulled from Open Weather Map
# kutum ID: 371745 has been pulled from Open Weather Map
# taltal ID: 3870243 has been pulled from Open Weather Map
# sinnamary ID: 3380290 has been pulled from Open Weather Map
# garissa ID: 197745 has been pulled from Open Weather Map
# guerrero negro ID: 4021858 has been pulled from Open Weather Map
# husavik ID: 2629833 has been pulled from Open Weather Map
# hobart ID: 2163355 has been pulled from Open Weather Map
# barbar not found, going to keep going!
# viligili not found, going to keep going!
# batemans bay ID: 2176639 has been pulled from Open Weather Map
# qaanaaq ID: 3831208 has been pulled from Open Weather Map
# beyneu ID: 610298 has been pulled from Open Weather Map
# vao ID: 2137773 has been pulled from Open Weather Map
# zeya ID: 2012593 has been pulled from Open Weather Map
# duz not found, going to keep going!
# jizan ID: 105298 has been pulled from Open Weather Map
# davila ID: 1715335 has been pulled from Open Weather Map
# concepcion ID: 3893894 has been pulled from Open Weather Map
# cherskiy ID: 2126199 has been pulled from Open Weather Map
# katiola ID: 2287298 has been pulled from Open Weather Map
# mecca ID: 104515 has been pulled from Open Weather Map
# upernavik ID: 3418910 has been pulled from Open Weather Map
# kvitok ID: 1501036 has been pulled from Open Weather Map
# oranjemund ID: 3354071 has been pulled from Open Weather Map
# lolua not found, going to keep going!
# nikolo-pavlovskoye ID: 1497654 has been pulled from Open Weather Map
# airai ID: 1651810 has been pulled from Open Weather Map
# ribeira grande ID: 3372707 has been pulled from Open Weather Map
# quatre cocos ID: 1106643 has been pulled from Open Weather Map
# namwala ID: 901766 has been pulled from Open Weather Map
# carnarvon ID: 2074865 has been pulled from Open Weather Map
# liverpool ID: 2644210 has been pulled from Open Weather Map
# mirnyy ID: 2019951 has been pulled from Open Weather Map
# tigil ID: 2120612 has been pulled from Open Weather Map
# kerrobert ID: 5991284 has been pulled from Open Weather Map
# san andres ID: 3670218 has been pulled from Open Weather Map
# lodwar ID: 189280 has been pulled from Open Weather Map
# tommot ID: 2015179 has been pulled from Open Weather Map
# acapulco ID: 3533462 has been pulled from Open Weather Map
# mar del plata ID: 3430863 has been pulled from Open Weather Map
# alta floresta ID: 6316343 has been pulled from Open Weather Map
# otradnoye ID: 513898 has been pulled from Open Weather Map
# plover ID: 5267537 has been pulled from Open Weather Map
# nikolayevsk-na-amure ID: 2122850 has been pulled from Open Weather Map
# mount isa ID: 2065594 has been pulled from Open Weather Map
# eureka ID: 5563397 has been pulled from Open Weather Map
# tasiilaq ID: 3424607 has been pulled from Open Weather Map
# sampit ID: 1628884 has been pulled from Open Weather Map
# butaritari ID: 2110227 has been pulled from Open Weather Map
# belushya guba not found, going to keep going!
# lagoa ID: 3372964 has been pulled from Open Weather Map
# kurumkan ID: 2021188 has been pulled from Open Weather Map
# hay river ID: 5972762 has been pulled from Open Weather Map
# gazojak ID: 1514792 has been pulled from Open Weather Map
# northam ID: 2641434 has been pulled from Open Weather Map
# sa kaeo ID: 1606807 has been pulled from Open Weather Map
# clarence town ID: 2171465 has been pulled from Open Weather Map
# tromso ID: 6453316 has been pulled from Open Weather Map
# kudahuvadhoo ID: 1337607 has been pulled from Open Weather Map
# pitimbu ID: 3391889 has been pulled from Open Weather Map
# moyo ID: 229059 has been pulled from Open Weather Map
# dakar ID: 2253354 has been pulled from Open Weather Map
# sorland ID: 3137469 has been pulled from Open Weather Map
# atlantic beach ID: 4146354 has been pulled from Open Weather Map
# dickinson ID: 4686163 has been pulled from Open Weather Map
# amapa ID: 3407762 has been pulled from Open Weather Map
# fairbanks ID: 5861897 has been pulled from Open Weather Map
# bethel ID: 5282297 has been pulled from Open Weather Map
# barth ID: 2952372 has been pulled from Open Weather Map
# tuatapere ID: 2180815 has been pulled from Open Weather Map
# yenagoa ID: 2318123 has been pulled from Open Weather Map
# egvekinot ID: 4031742 has been pulled from Open Weather Map
# meyungs not found, going to keep going!
# cabra ID: 2520645 has been pulled from Open Weather Map
# vieux-habitants ID: 3578278 has been pulled from Open Weather Map
# zyryanovskiy not found, going to keep going!
# blumberg ID: 2947584 has been pulled from Open Weather Map
# bonthe ID: 2409914 has been pulled from Open Weather Map
# rodrigues alves ID: 3665210 has been pulled from Open Weather Map
# beloha ID: 1067565 has been pulled from Open Weather Map
# namibe ID: 3347019 has been pulled from Open Weather Map
# rio cuarto ID: 3838874 has been pulled from Open Weather Map
# conceicao da barra ID: 3465769 has been pulled from Open Weather Map
# karratha ID: 6620339 has been pulled from Open Weather Map
# sorsk ID: 1491360 has been pulled from Open Weather Map
# cayenne ID: 3382160 has been pulled from Open Weather Map
# clyde river ID: 5924351 has been pulled from Open Weather Map
# luderitz ID: 3355672 has been pulled from Open Weather Map
# kaniama ID: 214389 has been pulled from Open Weather Map
# opochka ID: 515155 has been pulled from Open Weather Map
# nouadhibou ID: 2377457 has been pulled from Open Weather Map
# kuruman ID: 986134 has been pulled from Open Weather Map
# glotovka ID: 561179 has been pulled from Open Weather Map
# gayeri ID: 2360541 has been pulled from Open Weather Map
# havelock ID: 4470244 has been pulled from Open Weather Map
# karmana not found, going to keep going!
# tekeli ID: 1518296 has been pulled from Open Weather Map
# talara ID: 3691582 has been pulled from Open Weather Map
# halalo not found, going to keep going!
# avera ID: 4231997 has been pulled from Open Weather Map
# krasnokamensk ID: 2021618 has been pulled from Open Weather Map
# pangnirtung ID: 6096551 has been pulled from Open Weather Map
# camacha ID: 2270385 has been pulled from Open Weather Map
# great yarmouth ID: 2647984 has been pulled from Open Weather Map
# havoysund ID: 779622 has been pulled from Open Weather Map
# laguna ID: 5364271 has been pulled from Open Weather Map
# faanui ID: 4034551 has been pulled from Open Weather Map
# walvis bay ID: 3359638 has been pulled from Open Weather Map
# chilon ID: 3530871 has been pulled from Open Weather Map
# patrocinio ID: 3454763 has been pulled from Open Weather Map
# skjervoy ID: 777682 has been pulled from Open Weather Map
# birjand ID: 140463 has been pulled from Open Weather Map
# bumba ID: 217745 has been pulled from Open Weather Map
# galgani not found, going to keep going!
# koboko ID: 230725 has been pulled from Open Weather Map
# sao jose da coroa grande ID: 3388456 has been pulled from Open Weather Map
# xiongyue ID: 2033630 has been pulled from Open Weather Map
# jackson ID: 5733351 has been pulled from Open Weather Map
# marang ID: 1734715 has been pulled from Open Weather Map
# coquimbo ID: 3893629 has been pulled from Open Weather Map
# ostrovnoy ID: 556268 has been pulled from Open Weather Map
# sentyabrskiy not found, going to keep going!
# bathsheba ID: 3374083 has been pulled from Open Weather Map
# chokurdakh ID: 2126123 has been pulled from Open Weather Map
# tutoia ID: 3385899 has been pulled from Open Weather Map
# papara ID: 3395473 has been pulled from Open Weather Map
# sur ID: 286245 has been pulled from Open Weather Map
# serowe ID: 933088 has been pulled from Open Weather Map
# severo-kurilsk ID: 2121385 has been pulled from Open Weather Map
# denpasar ID: 1645528 has been pulled from Open Weather Map
# taoudenni ID: 2450173 has been pulled from Open Weather Map
# ambulu ID: 1621313 has been pulled from Open Weather Map
# cordoba ID: 3860259 has been pulled from Open Weather Map
# leh ID: 1264976 has been pulled from Open Weather Map
# yaan ID: 2338660 has been pulled from Open Weather Map
# ankara ID: 323786 has been pulled from Open Weather Map
# tiksi ID: 2015306 has been pulled from Open Weather Map
# freeport ID: 5117949 has been pulled from Open Weather Map
# usinsk ID: 863061 has been pulled from Open Weather Map
# tessalit ID: 2449893 has been pulled from Open Weather Map
# marawi ID: 1701054 has been pulled from Open Weather Map
# iqaluit ID: 5983720 has been pulled from Open Weather Map
# kampong thum ID: 1831125 has been pulled from Open Weather Map
# snezhnogorsk ID: 795243 has been pulled from Open Weather Map
# dzhebariki-khaya ID: 2024626 has been pulled from Open Weather Map
# bay roberts ID: 5895424 has been pulled from Open Weather Map
# aykhal ID: 2027296 has been pulled from Open Weather Map
# shingu ID: 1847947 has been pulled from Open Weather Map
# asfi ID: 2537881 has been pulled from Open Weather Map
# ranfurly ID: 2183774 has been pulled from Open Weather Map
# jiuquan ID: 1279945 has been pulled from Open Weather Map
# tura ID: 1254046 has been pulled from Open Weather Map
# rio bueno ID: 3873145 has been pulled from Open Weather Map
# registro ID: 3451704 has been pulled from Open Weather Map
# alihe ID: 2038665 has been pulled from Open Weather Map
# safranbolu ID: 740430 has been pulled from Open Weather Map
# japura ID: 1642773 has been pulled from Open Weather Map
# zonguldak ID: 737021 has been pulled from Open Weather Map
# muros ID: 3115824 has been pulled from Open Weather Map
# biak ID: 1637001 has been pulled from Open Weather Map
# merauke ID: 2082539 has been pulled from Open Weather Map
# gizo ID: 2108857 has been pulled from Open Weather Map
# krasnoye ID: 704277 has been pulled from Open Weather Map
# opelousas ID: 4336153 has been pulled from Open Weather Map
# minden ID: 2871039 has been pulled from Open Weather Map
# kalmunai ID: 1242110 has been pulled from Open Weather Map

# %%
DataFrame= pd.DataFrame({'City':cities,'Cloudiness':cloudiness,'Country':country,'Date':date,'Humidity':humidity,
                       'Lat':lat,'Lng':lng,'Max Temp':max_temp,'Wind Speed':wind_speed})

DataFrame.head()

# %%
DataFrame.to_csv("C:/Users/User/api-homework/DataFrame_Output.csv")

# %%
plt.scatter(DataFrame['Lat'], DataFrame["Max Temp"])

plt.title(f'City Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsTemperature Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Humidity'])

plt.title(f'City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsHumidity Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Cloudiness'])

plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsCloudiness Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Wind Speed'])

plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsWind Speed Plot.png")
plt.show()

# %%
def Lin_Reg(latitude, variable):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, variable)
    regress_values = latitude * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(latitude, variable)
    plt.plot(latitude,regress_values,"r-")
    plt.annotate(line_eq,(max(latitude)-6,max(variable)-10),fontsize=15,color="red")
    return rvalue

# %%
Northern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]>0),:]
Northern_Hemisphere_df

# %%
Southern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]<0),:]
Southern_Hemisphere_df.head()

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Max Temp"])

plt.title('Northern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Max Temp"])

plt.title('Southern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Humidity"])

plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Humidity"])

plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Cloudiness"])

plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Cloudiness"])

plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Wind Speed"])

plt.title('Northern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Wind Speed"])

plt.title('Southern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
