# %%
# Import API key
weather_api_key="d0cb7612d8e4acdc7e895ce9b00e46a3"

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
output_data_file ="C:/Users/User/Api Homework/Cities.csv"

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)

lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=200)
lngs = np.random.uniform(low=-180.000, high=180.000, size=200)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 146

# %%
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
lat = []
lng = []
country = []
date = []
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
key = weather_api_key


query_url = f"{url}appid={key}&units={units}&q="

response = requests.get(query_url + city).json()
response
# Out:
# {'coord': {'lon': -151.75, 'lat': -16.48},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 82.72,
#   'feels_like': 86.27,
#   'temp_min': 82.72,
#   'temp_max': 82.72,
#   'pressure': 1015,
#   'humidity': 73,
#   'sea_level': 1015,
#   'grnd_level': 1014},
#  'wind': {'speed': 10.22, 'deg': 71},
#  'clouds': {'all': 87},
#  'dt': 1583963932,
#  'sys': {'country': 'PF', 'sunrise': 1583942967, 'sunset': 1583987062},
#  'timezone': -36000,
#  'id': 4034551,
#  'name': 'Faanui',
#  'cod': 200}

# %%
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        id = response['id']
        country.append(response['sys']['country'])
        date.append(response['dt'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        print (f"{city} ID: {id} has been pulled from Open Weather Map")
    except (KeyError, IndexError):
        country.append(None)
        date.append(None)
        lat.append(None)
        lng.append(None)
        max_temp.append(None)
        humidity.append(None)
        cloudiness.append(None)
        wind_speed.append(None)
        print(f"{city} not found, going to keep going!")
# Out:
# saint-augustin ID: 6137462 has been pulled from Open Weather Map
# nizhneyansk not found, going to keep going!
# camara de lobos ID: 2270380 has been pulled from Open Weather Map
# iqaluit ID: 5983720 has been pulled from Open Weather Map
# san patricio ID: 3985168 has been pulled from Open Weather Map
# prince rupert ID: 6113406 has been pulled from Open Weather Map
# ushuaia ID: 3833367 has been pulled from Open Weather Map
# puerto ayora ID: 3652764 has been pulled from Open Weather Map
# albany ID: 5106841 has been pulled from Open Weather Map
# sechenovo ID: 497984 has been pulled from Open Weather Map
# srednekolymsk ID: 2121025 has been pulled from Open Weather Map
# luanda ID: 2240449 has been pulled from Open Weather Map
# ola ID: 2122574 has been pulled from Open Weather Map
# manhattan ID: 5125771 has been pulled from Open Weather Map
# batsfjord ID: 780717 has been pulled from Open Weather Map
# barrow ID: 5880054 has been pulled from Open Weather Map
# vostok ID: 2013279 has been pulled from Open Weather Map
# port alfred ID: 964432 has been pulled from Open Weather Map
# kapaa ID: 5848280 has been pulled from Open Weather Map
# castro ID: 3466704 has been pulled from Open Weather Map
# los llanos de aridane ID: 2514651 has been pulled from Open Weather Map
# zhigansk ID: 2012530 has been pulled from Open Weather Map
# cape town ID: 3369157 has been pulled from Open Weather Map
# kaitangata ID: 2208248 has been pulled from Open Weather Map
# hofn ID: 2630299 has been pulled from Open Weather Map
# lompoc ID: 5367788 has been pulled from Open Weather Map
# illoqqortoormiut not found, going to keep going!
# butaritari ID: 2110227 has been pulled from Open Weather Map
# faanui ID: 4034551 has been pulled from Open Weather Map
# prokhorovka ID: 504915 has been pulled from Open Weather Map

# %%
DataFrame= pd.DataFrame({'City':cities,'Cloudiness':cloudiness,'Country':country,'Date':date,'Humidity':humidity,
                       'Lat':lat,'Lng':lng,'Max Temp':max_temp,'Wind Speed':wind_speed})

DataFrame.head()
# Out:
#               City  Cloudiness Country          Date  Humidity    Lat     Lng  \
# 0   saint-augustin       100.0      CA  1.583964e+09      90.0  51.23  -58.65
# 1      nizhneyansk         NaN    None           NaN       NaN    NaN     NaN
# 2  camara de lobos        20.0      PT  1.583964e+09      72.0  32.63  -16.97
# 3          iqaluit        20.0      CA  1.583964e+09      63.0  63.75  -68.51
# 4     san patricio        40.0      MX  1.583964e+09      74.0  19.22 -104.70
#
#    Max Temp  Wind Speed
# 0     16.83       17.54
# 1       NaN         NaN
# 2     62.60       18.34
# 3     -9.00       11.41
# 4     80.60       13.87

# %%
DataFrame.to_csv("C:/Users/User/api-homework/DataFrame_Output.csv")

# %%
plt.scatter(DataFrame['Lat'], DataFrame["Max Temp"])

plt.title(f'City Latitude vs. Max Temperature (F)')
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsTemperature Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Humidity'])

plt.title(f'City Latitude vs. Humidity (%)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsHumidity Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Cloudiness'])

plt.title(f'City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsCloudiness Plot.png")
plt.show()

# %%
plt.scatter(DataFrame['Lat'], DataFrame['Wind Speed'])

plt.title(f'City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid(True)

plt.savefig("C:/Users/User/api-homework/LatitudevsWind Speed Plot.png")
plt.show()

# %%
def Lin_Reg(latitude, variable):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(latitude, variable)
    regress_values = latitude * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(latitude, variable)
    plt.plot(latitude,regress_values,"r-")
    plt.annotate(line_eq,(max(latitude)-6,max(variable)-10),fontsize=15,color="red")
    return rvalue

# %%
Northern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]>0),:]
Northern_Hemisphere_df
# Out:
#                 City  Cloudiness Country          Date  Humidity    Lat  \
# 0     saint-augustin       100.0      CA  1.583964e+09      90.0  51.23
# 2    camara de lobos        20.0      PT  1.583964e+09      72.0  32.63
# 3            iqaluit        20.0      CA  1.583964e+09      63.0  63.75
# 4       san patricio        40.0      MX  1.583964e+09      74.0  19.22
# 5      prince rupert        75.0      CA  1.583964e+09      65.0  54.32
# ..               ...         ...     ...           ...       ...    ...
# 141            wagar         0.0      SD  1.583964e+09      58.0  16.15
# 142           kachug        92.0      RU  1.583964e+09      97.0  53.96
# 143   krasnovishersk       100.0      RU  1.583964e+09      96.0  60.41
# 144            aswan       100.0      EG  1.583964e+09      33.0  24.09
# 145      prokhorovka        75.0      RU  1.583964e+09      75.0  51.04
#
#         Lng  Max Temp  Wind Speed
# 0    -58.65     16.83       17.54
# 2    -16.97     62.60       18.34
# 3    -68.51     -9.00       11.41
# 4   -104.70     80.60       13.87
# 5   -130.32     39.20       16.11
# ..      ...       ...         ...
# 141   36.20     77.54       10.54
# 142  105.88      0.48        2.24
# 143   57.08     32.99        9.62
# 144   32.91     79.66       19.44
# 145   36.73     46.40       15.66
#
# [86 rows x 9 columns]

# %%
Southern_Hemisphere_df = DataFrame.loc[(DataFrame["Lat"]<0),:]
Southern_Hemisphere_df.head()
# Out:
#             City  Cloudiness Country          Date  Humidity    Lat    Lng  \
# 6        ushuaia        90.0      AR  1.583964e+09      81.0 -54.80 -68.30
# 7   puerto ayora        20.0      EC  1.583964e+09      74.0  -0.74 -90.35
# 11        luanda        82.0      AO  1.583964e+09      76.0  -8.84  13.23
# 17   port alfred       100.0      ZA  1.583964e+09      92.0 -33.59  26.89
# 19        castro         0.0      BR  1.583964e+09      63.0 -24.79 -50.01
#
#     Max Temp  Wind Speed
# 6      48.20       12.75
# 7      84.20       11.41
# 11     81.64        5.37
# 17     68.00        1.99
# 19     72.82        2.82

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Max Temp"])

plt.title('Northern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')

print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8604042843283385

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Max Temp"])

plt.title('Southern Hemisphere - Max Temperature (F) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.7797855965284405

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Humidity"])

plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.4750348693083543

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Humidity"])

plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.028159522409891804

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Cloudiness"])

plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.2067145657738108

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Cloudiness"])

plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: -0.06065645525527951

# %%
shown_rvalue=Lin_Reg(Northern_Hemisphere_df["Lat"],Northern_Hemisphere_df["Wind Speed"])

plt.title('Northern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: 0.17280935578053394

# %%
shown_rvalue=Lin_Reg(Southern_Hemisphere_df["Lat"],Southern_Hemisphere_df["Wind Speed"])

plt.title('Southern Hemisphere - Win Speed (mph) vs. Latitude Linear Regression')
plt.xlabel('Latitude')
plt.ylabel('Win Speed (mph)')
print(f"The r-squared is: {shown_rvalue}")
plt.show()
# Out:
# The r-squared is: -0.16343619289755862
